# %%
#Estruturas de Dados
temperaturas = [30 ,35 ,40 , 42 ,45 ,38 , 37]
print(temperaturas)
# Out:
# [30, 35, 40, 42, 45, 38, 37]

# %%
print(temperaturas[0])
# Out:
# 30

# %%
print(f"O primeiro registro de temperatura foi de {temperaturas[0]} graus")
# Out:
# O primeiro registro de temperatura foi de 30 graus

# %%
temperaturas[0] = 35
print(temperaturas)

# %%
temperaturas.remove(35)
print(temperaturas)
# Out:
# [30, 40, 42, 45, 38, 37]

# %%
temperaturas.remove(temperaturas[0])
print(temperaturas)
# Out:
# [40, 42, 45, 38, 37]

# %%
lista = []
while len(lista) < 3:
    item = input("Digite os produtos da sua lista")
    lista.append(item)
print(lista)
# Out:
# ['banana', 'gabi gol', 'carro']
